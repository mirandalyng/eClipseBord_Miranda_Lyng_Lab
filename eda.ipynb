# %% [markdown]
# # EDA

# %% [markdown]
# In this simplified EDA following questions are answered
#
# * Dimensions: amount of columns and rows
#
# * Datatypes: numeric, categorigal, dates, text?
#
# * missing values (missing data)
#
# * Duplicated rows
#
# * Numereric values

# %%
import pandas as pd
from backend.constants import DATA_PATH

# %% [markdown]
# ## SOLAR DATASET

# %%
solar_df = pd.read_csv(DATA_PATH/"solar.csv")

solar_df

# %%
solar_df.shape
# Out:
# (11898, 15)

# %%
solar_df.dtypes
# Out:
# Catalog Number         int64
# Calendar Date            str
# Eclipse Time             str
# Delta T (s)            int64
# Lunation Number        int64
# Saros Number           int64
# Eclipse Type             str
# Gamma                float64
# Eclipse Magnitude    float64
# Latitude                 str
# Longitude                str
# Sun Altitude           int64
# Sun Azimuth            int64
# Path Width (km)          str
# Central Duration         str
# dtype: object

# %%
solar_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 11898 entries, 0 to 11897
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Catalog Number     11898 non-null  int64
#  1   Calendar Date      11898 non-null  str
#  2   Eclipse Time       11898 non-null  str
#  3   Delta T (s)        11898 non-null  int64
#  4   Lunation Number    11898 non-null  int64
#  5   Saros Number       11898 non-null  int64
#  6   Eclipse Type       11898 non-null  str
#  7   Gamma              11898 non-null  float64
#  8   Eclipse Magnitude  11898 non-null  float64
#  9   Latitude           11898 non-null  str
#  10  Longitude          11898 non-null  str
#  11  Sun Altitude       11898 non-null  int64
#  12  Sun Azimuth        11898 non-null  int64
#  13  Path Width (km)    7698 non-null   str
#  14  Central Duration   7698 non-null   str
# dtypes: float64(2), int64(6), str(7)
# memory usage: 1.8 MB

# %%
solar_df.columns
# Out:
# Index(['Catalog Number', 'Calendar Date', 'Eclipse Time', 'Delta T (s)',
#        'Lunation Number', 'Saros Number', 'Eclipse Type', 'Gamma',
#        'Eclipse Magnitude', 'Latitude', 'Longitude', 'Sun Altitude',
#        'Sun Azimuth', 'Path Width (km)', 'Central Duration'],
#       dtype='str')

# %%
solar_df.head()
# Out:
#    Catalog Number      Calendar Date Eclipse Time  Delta T (s)  \
# 0               1      -1999 June 12     03:14:51        46438
# 1               2   -1999 December 5     23:45:23        46426
# 2               3       -1998 June 1     18:09:16        46415
# 3               4  -1998 November 25     05:57:03        46403
# 4               5     -1997 April 22     13:19:56        46393
#
#    Lunation Number  Saros Number Eclipse Type   Gamma  Eclipse Magnitude  \
# 0           -49456             5            T -0.2701             1.0733
# 1           -49450            10            A -0.2317             0.9382
# 2           -49444            15            T  0.4994             1.0284
# 3           -49438            20            A -0.9045             0.9806
# 4           -49433           -13            P -1.4670             0.1611
#
#   Latitude Longitude  Sun Altitude  Sun Azimuth Path Width (km)  \
# 0     6.0N     33.3W            74          344             247
# ...

# %%
solar_df.isna().sum()
# Out:
# Catalog Number          0
# Calendar Date           0
# Eclipse Time            0
# Delta T (s)             0
# Lunation Number         0
# Saros Number            0
# Eclipse Type            0
# Gamma                   0
# Eclipse Magnitude       0
# Latitude                0
# Longitude               0
# Sun Altitude            0
# Sun Azimuth             0
# Path Width (km)      4200
# Central Duration     4200
# dtype: int64

# %%
solar_df.describe()
# Out:
#        Catalog Number   Delta T (s)  Lunation Number  Saros Number  \
# count    11898.000000  11898.000000     11898.000000  11898.000000
# mean      5949.500000  12142.172802    -18546.959321     87.483190
# std       3434.801086  13583.402888     17906.572982     48.380284
# min          1.000000     -6.000000    -49456.000000    -13.000000
# 25%       2975.250000    970.250000    -33954.750000     47.000000
# 50%       5949.500000   5636.500000    -18495.000000     87.000000
# 75%       8923.750000  20943.500000     -3039.250000    128.000000
# max      11898.000000  46438.000000     12378.000000    190.000000
#
#               Gamma  Eclipse Magnitude  Sun Altitude   Sun Azimuth
# count  11898.000000       11898.000000  11898.000000  11898.000000
# mean      -0.002469           0.812748     36.505295    180.264330
# std        0.900860           0.300398     32.417350    110.745408
# min       -1.569000           0.000000      0.000000      0.000000
# ...

# %%
solar_df[solar_df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Catalog Number, Calendar Date, Eclipse Time, Delta T (s), Lunation Number, Saros Number, Eclipse Type, Gamma, Eclipse Magnitude, Latitude, Longitude, Sun Altitude, Sun Azimuth, Path Width (km), Central Duration]
# Index: []

# %%
solar_df.describe().T
# Out:
#                      count          mean           std        min  \
# Catalog Number     11898.0   5949.500000   3434.801086      1.000
# Delta T (s)        11898.0  12142.172802  13583.402888     -6.000
# Lunation Number    11898.0 -18546.959321  17906.572982 -49456.000
# Saros Number       11898.0     87.483190     48.380284    -13.000
# Gamma              11898.0     -0.002469      0.900860     -1.569
# Eclipse Magnitude  11898.0      0.812748      0.300398      0.000
# Sun Altitude       11898.0     36.505295     32.417350      0.000
# Sun Azimuth        11898.0    180.264330    110.745408      0.000
#
#                             25%          50%         75%         max
# Catalog Number      2975.250000   5949.50000   8923.7500  11898.0000
# Delta T (s)          970.250000   5636.50000  20943.5000  46438.0000
# Lunation Number   -33954.750000 -18495.00000  -3039.2500  12378.0000
# Saros Number          47.000000     87.00000    128.0000    190.0000
# ...

# %% [markdown]
# ## LUNAR DATASET

# %%
lunar_df = pd.read_csv(DATA_PATH/"lunar.csv")

lunar_df
# Out:
#        Catalog Number      Calendar Date Eclipse Time  Delta T (s)  \
# 0                   1      -1999 June 26     14:13:28        46437
# 1                   2  -1999 November 21     20:23:49        46427
# 2                   3       -1998 May 17     05:47:36        46416
# 3                   4  -1998 November 11     05:15:58        46404
# 4                   5        -1997 May 6     18:57:01        46392
# ...               ...                ...          ...          ...
# 12059           12060        2999 May 21     13:21:13         4417
# 12060           12061   2999 November 14     16:41:25         4421
# 12061           12062        3000 May 10     15:00:16         4424
# 12062           12063     3000 October 5     17:10:38         4427
# 12063           12064    3000 November 4     05:45:18         4428
#
#        Lunation Number  Saros Number Eclipse Type Quincena Solar Eclipse  \
# 0               -49456            17            N                     t-
# ...

# %%
lunar_df.shape
# Out:
# (12064, 16)

# %%
lunar_df.dtypes
# Out:
# Catalog Number                      int64
# Calendar Date                         str
# Eclipse Time                          str
# Delta T (s)                         int64
# Lunation Number                     int64
# Saros Number                        int64
# Eclipse Type                          str
# Quincena Solar Eclipse                str
# Gamma                             float64
# Penumbral Magnitude               float64
# Umbral Magnitude                  float64
# Latitude                              str
# Longitude                             str
# Penumbral Eclipse Duration (m)    float64
# Partial Eclipse Duration (m)          str
# Total Eclipse Duration (m)            str
# dtype: object

# %%
lunar_df.describe()
# Out:
#        Catalog Number   Delta T (s)  Lunation Number  Saros Number  \
# count    12064.000000  12064.000000     12064.000000  12064.000000
# mean      6032.500000  12116.476044    -18531.392822     80.505056
# std       3482.721158  13584.785584     17887.218741     48.416007
# min          1.000000     -6.000000    -49456.000000    -20.000000
# 25%       3016.750000    962.000000    -33923.250000     40.000000
# 50%       6032.500000   5597.000000    -18445.500000     80.000000
# 75%       9048.250000  20901.500000     -3067.750000    121.000000
# max      12064.000000  46437.000000     12378.000000    183.000000
#
#               Gamma  Penumbral Magnitude  Umbral Magnitude  \
# count  12064.000000         12064.000000      12064.000000
# mean       0.002490             1.418656          0.400175
# std        0.910505             0.832263          0.832954
# min       -1.582700             0.000400         -1.095800
# 25%       -0.788825             0.684425         -0.334000
# ...

# %%
lunar_df.columns
# Out:
# Index(['Catalog Number', 'Calendar Date', 'Eclipse Time', 'Delta T (s)',
#        'Lunation Number', 'Saros Number', 'Eclipse Type',
#        'Quincena Solar Eclipse', 'Gamma', 'Penumbral Magnitude',
#        'Umbral Magnitude', 'Latitude', 'Longitude',
#        'Penumbral Eclipse Duration (m)', 'Partial Eclipse Duration (m)',
#        'Total Eclipse Duration (m)'],
#       dtype='str')

# %%
lunar_df.head()
# Out:
#    Catalog Number      Calendar Date Eclipse Time  Delta T (s)  \
# 0               1      -1999 June 26     14:13:28        46437
# 1               2  -1999 November 21     20:23:49        46427
# 2               3       -1998 May 17     05:47:36        46416
# 3               4  -1998 November 11     05:15:58        46404
# 4               5        -1997 May 6     18:57:01        46392
#
#    Lunation Number  Saros Number Eclipse Type Quincena Solar Eclipse   Gamma  \
# 0           -49456            17            N                     t- -1.0981
# 1           -49451           -16            N                     -a -1.1155
# 2           -49445           -11            P                     -t  0.8988
# 3           -49439            -6            P                     -a -0.4644
# 4           -49433            -1           T+                     pp  0.1003
#
#    Penumbral Magnitude  Umbral Magnitude Latitude Longitude  \
# ...

# %%
lunar_df.isna().sum()
# Out:
# Catalog Number                    0
# Calendar Date                     0
# Eclipse Time                      0
# Delta T (s)                       0
# Lunation Number                   0
# Saros Number                      0
# Eclipse Type                      0
# Quincena Solar Eclipse            0
# Gamma                             0
# Penumbral Magnitude               0
# Umbral Magnitude                  0
# Latitude                          0
# Longitude                         0
# Penumbral Eclipse Duration (m)    0
# Partial Eclipse Duration (m)      0
# Total Eclipse Duration (m)        0
# dtype: int64

# %%
lunar_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 12064 entries, 0 to 12063
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Catalog Number                  12064 non-null  int64
#  1   Calendar Date                   12064 non-null  str
#  2   Eclipse Time                    12064 non-null  str
#  3   Delta T (s)                     12064 non-null  int64
#  4   Lunation Number                 12064 non-null  int64
#  5   Saros Number                    12064 non-null  int64
#  6   Eclipse Type                    12064 non-null  str
#  7   Quincena Solar Eclipse          12064 non-null  str
#  8   Gamma                           12064 non-null  float64
#  9   Penumbral Magnitude             12064 non-null  float64
#  10  Umbral Magnitude                12064 non-null  float64
#  11  Latitude                        12064 non-null  str
# ...

# %%
lunar_df[lunar_df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Catalog Number, Calendar Date, Eclipse Time, Delta T (s), Lunation Number, Saros Number, Eclipse Type, Quincena Solar Eclipse, Gamma, Penumbral Magnitude, Umbral Magnitude, Latitude, Longitude, Penumbral Eclipse Duration (m), Partial Eclipse Duration (m), Total Eclipse Duration (m)]
# Index: []

# %%
lunar_df.describe().T
# Out:
#                                   count          mean           std  \
# Catalog Number                  12064.0   6032.500000   3482.721158
# Delta T (s)                     12064.0  12116.476044  13584.785584
# Lunation Number                 12064.0 -18531.392822  17887.218741
# Saros Number                    12064.0     80.505056     48.416007
# Gamma                           12064.0      0.002490      0.910505
# Penumbral Magnitude             12064.0      1.418656      0.832263
# Umbral Magnitude                12064.0      0.400175      0.832954
# Penumbral Eclipse Duration (m)  12064.0    269.971941     79.945444
#
#                                        min           25%          50%  \
# Catalog Number                      1.0000   3016.750000   6032.50000
# Delta T (s)                        -6.0000    962.000000   5597.00000
# Lunation Number                -49456.0000 -33923.250000 -18445.50000
# Saros Number                      -20.0000     40.000000     80.00000
# ...
